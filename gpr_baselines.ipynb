# 505  16-08-2023 10:15      40.0   60.0   35.6    1.8  227.0  26.227  84.357
# 506  16-08-2023 11:15      40.0   60.0   35.6    1.8  227.0  26.227  84.357
# 507  16-08-2023 12:15      40.0   60.0   35.6    1.8  227.0  26.227  84.357
# 508  16-08-2023 13:15      40.0   60.0   35.6    1.8  227.0  26.227  84.357
# 509  16-08-2023 14:15      40.0   60.0   35.6    1.8  227.0  26.227  84.357
#
# [510 rows x 99 columns]

# %%
lcs_data = pd.read_csv('data/AQI_LCS_data_prep.csv').iloc[:,1:]
lcs_data
# Out:
#                     Time  PM25_1201230029_ARARIA_ARARIA  \
# 0    2023-07-26 09:00:00                            8.0
# 1    2023-07-26 10:00:00                            6.0
# 2    2023-07-26 11:00:00                            6.5
# 3    2023-07-26 12:00:00                           13.0
# 4    2023-07-26 13:00:00                           10.0
# ..                   ...                            ...
# 505  2023-08-16 10:00:00                           41.0
# 506  2023-08-16 11:00:00                           36.0
# 507  2023-08-16 12:00:00                           29.0
# 508  2023-08-16 13:00:00                           21.0
# 509  2023-08-16 14:00:00                           17.5
#
#      Temp_1201230029_ARARIA_ARARIA  RH_1201230029_ARARIA_ARARIA  \
# 0                             32.0                         98.0
# 1                             33.0                         98.0
# 2                             34.5                         98.0
# 3                             33.5                         98.0
# 4                             34.0                         98.0
# ..                             ...                          ...
# 505                           34.5                         98.0
# 506                           35.5                         98.0
# 507                           36.0                         98.0
# 508                           36.0                         98.0
# 509                           36.0                         98.0
#
#      lat_PM25_1201230029_ARARIA_ARARIA  long_PM25_1201230029_ARARIA_ARARIA  \
# 0                               26.148                              87.457
# 1                               26.148                              87.457
# 2                               26.148                              87.457
# 3                               26.148                              87.457
# 4                               26.148                              87.457
# ..                                 ...                                 ...
# 505                             26.148                              87.457
# 506                             26.148                              87.457
# 507                             26.148                              87.457
# 508                             26.148                              87.457
# 509                             26.148                              87.457
#
#      PM25_1201230033_KURSAKANTA_ARARIA  Temp_1201230033_KURSAKANTA_ARARIA  \
# 0                                 26.0                               30.5
# 1                                 20.5                               30.5
# 2                                 12.5                               30.0
# 3                                 15.5                               30.0
# 4                                 10.0                               32.0
# ..                                 ...                                ...
# 505                               30.5                               41.5
# 506                               30.0                               41.5
# 507                               30.5                               41.5
# 508                               29.0                               41.0
# 509                               29.0                               41.0
#
#      RH_1201230033_KURSAKANTA_ARARIA  lat_PM25_1201230033_KURSAKANTA_ARARIA  \
# 0                               90.0                                 26.359
# 1                               90.0                                 26.359
# 2                               90.0                                 26.359
# 3                               88.0                                 26.359
# 4                               82.5                                 26.359
# ..                               ...                                    ...
# 505                             56.5                                 26.359
# 506                             54.0                                 26.359
# 507                             54.5                                 26.359
# 508                             57.0                                 26.359
# 509                             57.0                                 26.359
#
#      ...  PM25_BCDDC247BFE3_BHITAHA_WCHAMPARAN  \
# 0    ...                                 14.55
# 1    ...                                 11.22
# 2    ...                                 15.26
# 3    ...                                 37.81
# 4    ...                                 15.55
# ..   ...                                   ...
# 505  ...                                 30.40
# 506  ...                                 28.02
# 507  ...                                 28.00
# 508  ...                                 28.00
# 509  ...                                 28.00
#
#      Temp_BCDDC247BFE3_BHITAHA_WCHAMPARAN  RH_BCDDC247BFE3_BHITAHA_WCHAMPARAN  \
# 0                                   38.25                               50.36
# 1                                   38.82                               50.36
# 2                                   38.46                               50.36
# 3                                   39.47                               47.59
# 4                                   39.96                               46.83
# ..                                    ...                                 ...
# 505                                 36.23                               70.98
# 506                                 38.29                               62.14
# 507                                 38.60                               62.60
# 508                                 38.60                               62.60
# 509                                 38.60                               62.60
#
#      lat_PM25_BCDDC247BFE3_BHITAHA_WCHAMPARAN  \
# 0                                      26.907
# 1                                      26.907
# 2                                      26.907
# 3                                      26.907
# 4                                      26.907
# ..                                        ...
# 505                                    26.907
# 506                                    26.907
# 507                                    26.907
# 508                                    26.907
# 509                                    26.907
#
#      long_PM25_BCDDC247BFE3_BHITAHA_WCHAMPARAN  \
# 0                                       84.136
# 1                                       84.136
# 2                                       84.136
# 3                                       84.136
# 4                                       84.136
# ..                                         ...
# 505                                     84.136
# 506                                     84.136
# 507                                     84.136
# 508                                     84.136
# 509                                     84.136
#
#      PM25_DC4F22364445_PIPRASI_WCHAMPARAN  \
# 0                                   18.02
# 1                                   13.92
# 2                                   14.37
# 3                                   11.13
# 4                                   11.48
# ..                                    ...
# 505                                 33.65
# 506                                 33.32
# 507                                 30.00
# 508                                 30.00
# 509                                 30.00
#
#      Temp_DC4F22364445_PIPRASI_WCHAMPARAN  RH_DC4F22364445_PIPRASI_WCHAMPARAN  \
# 0                                   35.59                               57.30
# 1                                   36.46                               57.30
# 2                                   35.90                               57.30
# 3                                   36.68                               56.93
# 4                                   38.89                               51.65
# ..                                    ...                                 ...
# 505                                 35.33                               65.03
# 506                                 35.55                               64.64
# 507                                 36.20                               60.80
# 508                                 36.20                               60.80
# 509                                 36.20                               60.80
#
#      lat_PM25_DC4F22364445_PIPRASI_WCHAMPARAN  \
# 0                                       27.06
# 1                                       27.06
# 2                                       27.06
# 3                                       27.06
# 4                                       27.06
# ..                                        ...
# 505                                     27.06
# 506                                     27.06
# 507                                     27.06
# 508                                     27.06
# 509                                     27.06
#
#      long_PM25_DC4F22364445_PIPRASI_WCHAMPARAN
# 0                                       84.023
# 1                                       84.023
# 2                                       84.023
# 3                                       84.023
# 4                                       84.023
# ..                                         ...
# 505                                     84.023
# 506                                     84.023
# 507                                     84.023
# 508                                     84.023
# 509                                     84.023
#
# [510 rows x 1236 columns]

# %%
data.shape[1]/9
# Out:
# 11.0

# %%
(lcs_data.shape[1]-1)/5
# Out:
# 247.0

# %%
lcs_sensors = {}
for i in range(247):
    sensor = lcs_data.columns[5*i].split('_')[1]
    loc = (lcs_data.iloc[0,5*i+3],lcs_data.iloc[0,5*i+4])
    lcs_sensors[sensor]=loc

# %%
hcs_sensors = {}
for i in range(11):
    sensor = data.columns[9*i+2].split('_')[1]
    loc = (data.iloc[0,9*i+7],data.iloc[0,9*i+8])
    hcs_sensors[sensor] = loc

# %%
matching = {}
for sensor in lcs_sensors.keys():
    for tgt in hcs_sensors.keys():
        if lcs_sensors[sensor]== hcs_sensors[tgt]:
            matching[sensor] = tgt

# %%
matching
# Out:
# {'1212220152': '3',
#  '1201230089': '8',
#  '1203230019': '9',
#  '1211220066': '18',
#  '4C75250A4545': '17'}

# %%
coll_data = pd.DataFrame()
columns = ['Time']
for col in lcs_data.columns:
    if(col=='Time'):
        continue
    if col.split('_')[1] in matching.keys():
        columns.append(col)

# %%
columns
# Out:
# ['Time',
#  'PM25_1212220152_JAGDISHPUR.BG_BHAGALPUR',
#  'Temp_1212220152_JAGDISHPUR.BG_BHAGALPUR',
#  'RH_1212220152_JAGDISHPUR.BG_BHAGALPUR',
#  'PM25_1201230089_KATIHAR_KATIHAR',
#  'Temp_1201230089_KATIHAR_KATIHAR',
#  'RH_1201230089_KATIHAR_KATIHAR',
#  'PM25_1203230019_KISHANGANJ_KISHANGANJ',
#  'Temp_1203230019_KISHANGANJ_KISHANGANJ',
#  'RH_1203230019_KISHANGANJ_KISHANGANJ',
#  'PM25_1211220066_SIWAN_SIWAN',
#  'Temp_1211220066_SIWAN_SIWAN',
#  'RH_1211220066_SIWAN_SIWAN',
#  'PM25_4C75250A4545_HAJIPUR_VAISHALI',
#  'Temp_4C75250A4545_HAJIPUR_VAISHALI',
#  'RH_4C75250A4545_HAJIPUR_VAISHALI']

# %%
locations = ['BHAGALPUR','KATIHAR','SIWAN','KISHANGANJ','HAJIPUR']
data_dict = {}
for loc in locations:
    col_to_append = [col for col in columns if loc in col]
    df = pd.DataFrame()
    df['Time'] = lcs_data['Time']
    for c in col_to_append:
        if 'PM25' in c:
            df['PM25L'] = lcs_data[c]
        if 'Temp' in c:
            df['Temp'] = lcs_data[c]
        if 'RH' in c:
            df['RH'] = lcs_data[c]
    sensor = col_to_append[0].split('_')[1]
    matched = matching[sensor]
    df['PM25H'] = data[f'PM2.5_{matched}']

    data_dict[loc] = df

# %%
with open('data/collocated_sensor_dict.pkl','wb') as f:
    pickle.dump(data_dict,f)

# %%
with open('data/collocated_sensor_dict.pkl','rb') as f:
    my_dict = pickle.load(f)

# %%
locations = [['BHAGALPUR','KATIHAR','SIWAN','HAJIPUR']]

# %%
my_dict['BHAGALPUR']
# Out:
#                     Time  PM25L  Temp    RH  PM25H
# 0    2023-07-26 09:00:00   10.0  34.0  63.5   12.0
# 1    2023-07-26 10:00:00    8.5  35.5  63.5    7.0
# 2    2023-07-26 11:00:00    7.0  37.0  63.5    2.0
# 3    2023-07-26 12:00:00    9.0  38.0  60.0    6.0
# 4    2023-07-26 13:00:00    8.0  40.0  54.5   15.0
# ..                   ...    ...   ...   ...    ...
# 505  2023-08-16 10:00:00   39.5  35.5  77.0   36.0
# 506  2023-08-16 11:00:00   30.5  37.5  72.5   30.0
# 507  2023-08-16 12:00:00   32.5  38.5  69.0   34.0
# 508  2023-08-16 13:00:00   28.5  39.5  64.5   34.0
# 509  2023-08-16 14:00:00   30.0  40.0  61.0   20.0
#
# [510 rows x 5 columns]

# %%
scores = {}

# %%
test_loc = 'KATIHAR'

# %%
df_test = my_dict[test_loc].iloc[:,1:]
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_test),columns=df_test.columns)
X_test = df_scaled.iloc[:,:-1].values
y_test = df_scaled.iloc[:,-1].values

# %%
df = pd.concat([my_dict['BHAGALPUR'],my_dict['SIWAN'],my_dict['HAJIPUR']]).iloc[:,1:]

# %%
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df),columns = df.columns)
X = df_scaled.iloc[:,:-1].values
y = df['PM25H'].values

# %%
X_train,X_val,y_train,y_val = train_test_split(X,y,train_size=0.8)
print(f"X_train.shape {X_train.shape}")
print(f"y_train.shape {y_train.shape}")
print(f"X_val.shape {X_val.shape}")
print(f"y_val.shape {y_val.shape}")
print(f"X_test.shape {X_test.shape}")
print(f"y_test.shape {y_test.shape}")
# Out:
# X_train.shape (1224, 3)
# y_train.shape (1224,)
# X_val.shape (306, 3)
# y_val.shape (306,)
# X_test.shape (510, 3)
# y_test.shape (510,)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

kernel = DotProduct() + WhiteKernel()
model = GaussianProcessRegressor(kernel=kernel,alpha = 1)
model.fit(X_train,y_train)

y_pred = model.predict(X_train)

print(f"Train mae {mean_absolute_error(y_pred,y_train)}")
print(f"Train R2 {r2_score(y_pred,y_train)}")

y_pred = model.predict(X_val)

print(f"Val mae {mean_absolute_error(y_pred,y_val)}")
print(f"Val R2 {r2_score(y_pred,y_val)}")
# Out:
# Train mae 9.179947528728587
# Train R2 -2.503239381693813
# Val mae 8.71950790554787
# Val R2 -1.1309294051192533

# %%
from sklearn.metrics import r2_score, mean_absolute_error
y_pred = model.predict(X_test)
r2 = r2_score(y_pred,y_test)
print(f"r2-score {r2}")
mae = mean_absolute_error(y_pred,y_test)
print(f"mae score {mae}")

scores[test_loc] = {
    'r2':r2,
    'mae':mae

}
# Out:
# r2-score -9.356369420555431
# mae score 26.064142185928734

# %%
with open('logs/baselines/gpr.json','w') as f:
    json.dump(scores,f)
